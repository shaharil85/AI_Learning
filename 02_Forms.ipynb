# %% [markdown]
# <a href="https://colab.research.google.com/github/shaharil85/AI_Learning/blob/main/02_Forms.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title String fields

text = 'value' #@param {type:"string"}
dropdown = '1st option' #@param ["1st option", "2nd option", "3rd option"]
text_and_dropdown = '3rd option' #@param ["1st option", "2nd option", "3rd option"] {allow-input: true}

print(text)
print(dropdown)
print(text_and_dropdown)

# %%
#@title Date fields
date_input = '2018-03-22' #@param {type:"date"}

print(date_input)

# %% [markdown]
# Dynamic data population

# %%
from google.colab import widgets
import numpy as np
import random
import time
from matplotlib import pylab
grid = widgets.Grid(2, 2)
for i in range(20):
  with grid.output_to(random.randint(0, 1), random.randint(0, 1)):
    grid.clear_cell()
    pylab.figure(figsize=(2, 2))
    pylab.plot(np.random.random((10, 1)))
  time.sleep(0.5)
# Out:
# <style>
#        table#id2, #id2 > tbody > tr > th, #id2 > tbody > tr > td {
#          border: 1px solid lightgray;
#          border-collapse:collapse;
#
#         }</style>
# <table id=id2><tr><td id=id2-0-0></td><td id=id2-0-1></td></tr><tr><td id=id2-1-0></td><td id=id2-1-1></td></tr></table>
